# %% [markdown]
# # Mount drive

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# %cd "drive/My Drive/darknet"

# %%
# %ls

# %% [markdown]
# #Buid Darknet

# %% [markdown]
# ### Check GPU

# %%
# !nvidia-smi

# %% [markdown]
# ### If GPU == V100:

# %%
# !sed -i 's/CUDNN_HALF=0/CUDNN_HALF=1/g' Makefile
# !sed -i 's/# ARCH= -gencode arch=compute_70,code=[sm_70,compute_70]/ARCH= -gencode arch=compute_70,code=[sm_70,compute_70]/g' Makefile

# %% [markdown]
# ### Elif GPU == P100

# %%
# !sed -i 's/# ARCH= -gencode arch=compute_60,code=sm_60/ARCH= -gencode arch=compute_60,code=sm_60/g' Makefile

# %% [markdown]
# ### Else:

# %%
# !rm darknet

# %%
# !make

# %% [markdown]
# # Train

# %%
# !./darknet detector train data/obj.data cfg/custom/tiny-armoire.cfg weights/yolov3-tiny.conv.15 -map -dont_show

# %% [markdown]
# # Detect

# %%
# !./darknet detector test data/obj.data cfg/custom/tiny-armoire.cfg backup/tiny-armoire_last.weights data/obj/20191211_124041.jpg -dont_show

# %%
# !mv predictions.jpg predictions/predictions_03.jpg
