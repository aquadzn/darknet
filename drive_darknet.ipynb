# %% [markdown]
# # Mount drive

# %%
# %cd "drive/My Drive/darknet"
# Out:
# /content/drive/My Drive/darknet

# %%
# %ls
# Out:
# 3rdparty/  CadrePMZ/               DARKNET.ipynb        Makefile   scripts/
# backup/    cfg/                    darknet.py           models/    src/
# bad.list   cmake/                  data/                obj/       train.sh
# build/     CMakeLists.txt          Dockerfile           README.md  weights/
# build.ps1  darknet                 GaucheCentreDroite/  results/
# build.sh   DarknetConfig.cmake.in  include/             samples/

# %% [markdown]
# #Buid Darknet

# %% [markdown]
# ### Check GPU

# %%
# !nvidia-smi
# Out:
# Thu Apr  9 10:09:04 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 440.64.00    Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  Tesla P4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   31C    P8     6W /  75W |      0MiB /  7611MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# ...

# %% [markdown]
# ### If GPU == V100:

# %%
# !sed -i 's/CUDNN_HALF=0/CUDNN_HALF=1/g' Makefile
# !sed -i 's/# ARCH= -gencode arch=compute_70,code=[sm_70,compute_70]/ARCH= -gencode arch=compute_70,code=[sm_70,compute_70]/g' Makefile

# %% [markdown]
# ### Elif GPU == P100

# %%
# !sed -i 's/# ARCH= -gencode arch=compute_60,code=sm_60/ARCH= -gencode arch=compute_60,code=sm_60/g' Makefile

# %% [markdown]
# ### Else:

# %%
# !make

# %% [markdown]
# # Train

# %%
# !./darknet detector train ...

# %% [markdown]
# # Predict

# %% [markdown]
# # Nouvelle section

# %%
# !./darknet detector test data/obj.data cfg/custom/customv3-spp.cfg backup/csresnext50-panet-spp-obj_final.weights samples/test_8.jpg -dont_show
# Out:
#  CUDA-version: 10010 (10010), cuDNN: 7.6.5, GPU count: 1
#  OpenCV version: 3.2.0
#  compute_capability = 610, cudnn_half = 0
# net.optimized_memory = 0
# mini_batch = 1, batch = 16, time_steps = 1, train = 0
#    layer   filters  size/strd(dil)      input                output
#    0 conv     32       3 x 3/ 1    608 x 608 x   3 ->  608 x 608 x  32 0.639 BF
#    1 conv     64       3 x 3/ 2    608 x 608 x  32 ->  304 x 304 x  64 3.407 BF
#    2 conv     32       1 x 1/ 1    304 x 304 x  64 ->  304 x 304 x  32 0.379 BF
#    3 conv     64       3 x 3/ 1    304 x 304 x  32 ->  304 x 304 x  64 3.407 BF
#    4 Shortcut Layer: 1,  wt = 0, wn = 0, outputs: 304 x 304 x  64 0.006 BF
#    5 conv    128       3 x 3/ 2    304 x 304 x  64 ->  152 x 152 x 128 3.407 BF
#    6 conv     64       1 x 1/ 1    152 x 152 x 128 ->  152 x 152 x  64 0.379 BF
#    7 conv    128       3 x 3/ 1    152 x 152 x  64 ->  152 x 152 x 128 3.407 BF
# ...
